# %%
import matplotlib

# %%
matplotlib.use('Agg')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pickle

# %%
pickle_in = open("xgboost_4c_withmergediffparams.pkl","rb")
lr = pickle.load(pickle_in)

# %%
lr

# %%
from xgboost import plot_importance

# %%
plot_importance(lr)

# %%
plt.show()
